# %% [markdown]
# # Lung Cancer Prediction Model Using Support Vector Classification

# %% [markdown]
# ## Imports
# Numpy,
# Pandas,
# Sklearn &
# Matplotlib

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt

# %% [markdown]
# ## Narrowing Down To Fewer Columns

# %%
data = pd.read_csv("cancer patient data sets.csv")
data.pop('Patient Id')
data.pop('index')
data.pop('chronic Lung Disease')
data.pop('Balanced Diet')
data.pop('Air Pollution')
data.pop('Swallowing Difficulty')
data.pop('Fatigue')
data.pop('Clubbing of Finger Nails')
data.pop('Snoring')
data.pop('Coughing of Blood')
data.pop('OccuPational Hazards')
data.pop('Genetic Risk')
data.pop('Passive Smoker')
data.pop('Obesity')
data.pop('Frequent Cold')
data.pop('Weight Loss')

data
# Out:
#      Age  Gender  Alcohol use  Dust Allergy  Smoking  Chest Pain  \
# 0     33       1            4             5        3           2
# 1     17       1            1             5        2           2
# 2     35       1            5             6        2           4
# 3     37       1            7             7        7           7
# 4     46       1            8             7        8           7
# ..   ...     ...          ...           ...      ...         ...
# 995   44       1            7             7        7           7
# 996   37       2            8             7        7           7
# 997   25       2            5             6        2           4
# 998   18       2            8             7        8           7
# 999   47       1            5             6        2           4
#
#      Shortness of Breath  Wheezing  Dry Cough   Level
# 0                      2         2          3     Low
# 1                      7         8          7  Medium
# ...

# %% [markdown]
# ## Plotting Tabluar Data on X and y axis

# %%
X = np.array(data.drop('Level', axis=1))
y = np.array(data['Level'])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# ## Creating the Classification Model & Making Predictions

# %%
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
predictions = model.predict(x_test)

for x in range(len(predictions)):
    print(y_test[x],"\t-\t", predictions[x])
# Out:
# Low 	-	 High
# High 	-	 High
# Low 	-	 Low
# Medium 	-	 Medium
# High 	-	 High
# High 	-	 High
# Low 	-	 Low
# High 	-	 High
# Low 	-	 Low
# Low 	-	 Low
# High 	-	 High
# High 	-	 High
# High 	-	 High
# Medium 	-	 Medium
# High 	-	 High
# Low 	-	 High
# Medium 	-	 Medium
# High 	-	 High
# Low 	-	 Low
# Medium 	-	 Medium
# Low 	-	 Low
# High 	-	 High
# High 	-	 High
# Medium 	-	 Medium
# Medium 	-	 Medium
# High 	-	 High
# High 	-	 High
# High 	-	 High
# High 	-	 High
# Low 	-	 High
# Medium 	-	 Medium
# Low 	-	 Low
# High 	-	 High
# Low 	-	 Low
# Low 	-	 Low
# High 	-	 High
# High 	-	 High
# High 	-	 High
# High 	-	 High
# Low 	-	 Low
# Low 	-	 Medium
# High 	-	 High
# Low 	-	 Low
# Low 	-	 Low
# Medium 	-	 Medium
# High 	-	 High
# Medium 	-	 Medium
# High 	-	 High
# Medium 	-	 Medium
# High 	-	 High
# Low 	-	 Medium
# Low 	-	 Low
# Medium 	-	 Medium
# Medium 	-	 Medium
# High 	-	 High
# Low 	-	 Low
# High 	-	 High
# Low 	-	 Low
# Low 	-	 Low
# Low 	-	 High
# High 	-	 High
# ...

# %% [markdown]
# ## Calcluating & Displaying Accuracy

# %%
accuracy = accuracy_score(y_test, predictions)
print("Model Accuracy",accuracy*100,"%")
# Out:
# Model Accuracy 88.0 %
